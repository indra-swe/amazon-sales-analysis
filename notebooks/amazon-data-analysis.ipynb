# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv('../data/amazon.csv')

# %%
df.head()
# Out:
#    product_id                                       product_name  \
# 0  B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1  B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2  B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3  B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4  B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
#
#                                             category discounted_price  \
# 0  Computers&Accessories|Accessories&Peripherals|...             ₹399
# 1  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 2  Computers&Accessories|Accessories&Peripherals|...             ₹199
# 3  Computers&Accessories|Accessories&Peripherals|...             ₹329
# 4  Computers&Accessories|Accessories&Peripherals|...             ₹154
#
#   actual_price discount_percentage rating rating_count  \
# 0       ₹1,099                 64%    4.2       24,269
# 1         ₹349                 43%    4.0       43,994
# 2       ₹1,899                 90%    3.9        7,928
# 3         ₹699                 53%    4.2       94,363
# 4         ₹399                 61%    4.2       16,905
#
#                                        about_product  \
# 0  High Compatibility : Compatible With iPhone 12...
# 1  Compatible with all Type C enabled devices, be...
# 2  【 Fast Charger& Data Sync】-With built-in safet...
# 3  The boAt Deuce USB 300 2 in 1 cable is compati...
# 4  [CHARGE & SYNC FUNCTION]- This cable comes wit...
#
#                                              user_id  \
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
# 1  AECPFYFQVRUWC3KGNLJIOREFP5LQ,AGYYVPDD7YG7FYNBX...
# 2  AGU3BBQ2V2DDAMOAKGFAWDDQ6QHA,AESFLDV2PT363T2AQ...
# 3  AEWAZDZZJLQUYVOVGBEUKSLXHQ5A,AG5HTSFRRE6NL3M5S...
# 4  AE3Q6KSUK5P75D5HFYHCRAOLODSA,AFUGIFH5ZAFXRDSZH...
#
#                                            user_name  \
# 0  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
# 1  ArdKn,Nirbhay kumar,Sagar Viswanathan,Asp,Plac...
# 2  Kunal,Himanshu,viswanath,sai niharka,saqib mal...
# 3  Omkar dhale,JD,HEMALATHA,Ajwadh a.,amar singh ...
# 4  rahuls6099,Swasat Borah,Ajay Wadke,Pranali,RVK...
#
#                                            review_id  \
# 0  R3HXWT0LRP0NMF,R2AJM3LFTLZHFO,R6AQJGUP6P86,R1K...
# 1  RGIQEG07R9HS2,R1SMWZQ86XIN8U,R2J3Y1WL29GWDE,RY...
# 2  R3J3EQQ9TZI5ZJ,R3E7WBGK7ID0KV,RWU79XKQ6I1QF,R2...
# 3  R3EEUZKKK9J36I,R3HJVYCLYOY554,REDECAZ7AMPQC,R1...
# 4  R1BP4L2HH9TFUP,R16PVJEXKV6QZS,R2UPDB81N66T4P,R...
#
#                                         review_title  \
# 0  Satisfied,Charging is really fast,Value for mo...
# 1  A Good Braided Cable for Your Type C Device,Go...
# 2  Good speed for earlier versions,Good Product,W...
# 3  Good product,Good one,Nice,Really nice product...
# 4  As good as original,Decent,Good one for second...
#
#                                       review_content  \
# 0  Looks durable Charging is fine tooNo complains...
# 1  I ordered this cable to connect my phone to An...
# 2  Not quite durable and sturdy,https://m.media-a...
# 3  Good product,long wire,Charges good,Nice,I bou...
# 4  Bought this instead of original apple, does th...
#
#                                             img_link  \
# 0  https://m.media-amazon.com/images/W/WEBP_40237...
# 1  https://m.media-amazon.com/images/W/WEBP_40237...
# 2  https://m.media-amazon.com/images/W/WEBP_40237...
# 3  https://m.media-amazon.com/images/I/41V5FtEWPk...
# 4  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                         product_link
# 0  https://www.amazon.in/Wayona-Braided-WN3LG1-Sy...
# 1  https://www.amazon.in/Ambrane-Unbreakable-Char...
# 2  https://www.amazon.in/Sounce-iPhone-Charging-C...
# 3  https://www.amazon.in/Deuce-300-Resistant-Tang...
# 4  https://www.amazon.in/Portronics-Konnect-POR-1...

# %%
df.shape
# Out:
# (1465, 16)

# %%
df.columns
# Out:
# Index(['product_id', 'product_name', 'category', 'discounted_price',
#        'actual_price', 'discount_percentage', 'rating', 'rating_count',
#        'about_product', 'user_id', 'user_name', 'review_id', 'review_title',
#        'review_content', 'img_link', 'product_link'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1465 entries, 0 to 1464
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   product_id           1465 non-null   str
#  1   product_name         1465 non-null   str
#  2   category             1465 non-null   str
#  3   discounted_price     1465 non-null   str
#  4   actual_price         1465 non-null   str
#  5   discount_percentage  1465 non-null   str
#  6   rating               1465 non-null   str
#  7   rating_count         1463 non-null   str
#  8   about_product        1465 non-null   str
#  9   user_id              1465 non-null   str
#  10  user_name            1465 non-null   str
#  11  review_id            1465 non-null   str
#  12  review_title         1465 non-null   str
#  13  review_content       1465 non-null   str
#  14  img_link             1465 non-null   str
#  15  product_link         1465 non-null   str
# dtypes: str(16)
# memory usage: 183.3 KB

# %%
df.isnull().sum()
# Out:
# product_id             0
# product_name           0
# category               0
# discounted_price       0
# actual_price           0
# discount_percentage    0
# rating                 0
# rating_count           2
# about_product          0
# user_id                0
# user_name              0
# review_id              0
# review_title           0
# review_content         0
# img_link               0
# product_link           0
# dtype: int64

# %% [markdown]
# Which Category Exist?

# %%
df['category'].value_counts()
# Out:
# category
# Computers&Accessories|Accessories&Peripherals|Cables&Accessories|Cables|USBCables                                          233
# Electronics|WearableTechnology|SmartWatches                                                                                 76
# Electronics|Mobiles&Accessories|Smartphones&BasicMobiles|Smartphones                                                        68
# Electronics|HomeTheater,TV&Video|Televisions|SmartTelevisions                                                               63
# Electronics|Headphones,Earbuds&Accessories|Headphones|In-Ear                                                                52
#                                                                                                                           ...
# Home&Kitchen|Kitchen&HomeAppliances|SmallKitchenAppliances|RotiMakers                                                        1
# Home&Kitchen|Heating,Cooling&AirQuality|Parts&Accessories|FanParts&Accessories                                               1
# Home&Kitchen|Kitchen&HomeAppliances|SmallKitchenAppliances|StandMixers                                                       1
# Home&Kitchen|Heating,Cooling&AirQuality|Fans|PedestalFans                                                                    1
# Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cleaning&Ironing|Vacuums&FloorCare|VacuumAccessories|VacuumBags|HandheldBags      1
# Name: count, Length: 211, dtype: int64

# %% [markdown]
# Highest Rated Products?

# %%
df.sort_values(by='rating', ascending=False).head(10)
# Out:
#       product_id                                       product_name  \
# 1279  B08L12N5H1  Eureka Forbes car Vac 100 Watts Powerful Sucti...
# 324   B0BQRJ3C47  REDTECH USB-C to Lightning Cable 3.3FT, [Apple...
# 174   B0BP7XLX48  Syncwire LTG to USB Cable for Fast Charging Co...
# 775   B09ZHCJDP1  Amazon Basics Wireless Mouse | 2.4 GHz Connect...
# 1201  B0BQ3K23Y1  Oratech Coffee Frother electric, milk frother ...
# 1145  B0BR4F878Q  Swiffer Instant Electric Water Heater Faucet T...
# 1299  B0B53DS4TF  Instant Pot Air Fryer, Vortex 2QT, Touch Contr...
# 1223  B0BM4KTNL1  FIGMENT Handheld Milk Frother Rechargeable, 3-...
# 1388  B0BP89YBC1  Campfire Spring Chef Prolix Instant Portable W...
# 1275  B0BM9H2NY9  Multifunctional 2 in 1 Electric Egg Boiling St...
#
#                                                category discounted_price  \
# 1279  Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cle...           ₹2,099
# 324   Computers&Accessories|Accessories&Peripherals|...             ₹249
# 174   Computers&Accessories|Accessories&Peripherals|...             ₹399
# 775   Computers&Accessories|Accessories&Peripherals|...             ₹499
# 1201  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...             ₹279
# 1145  Home&Kitchen|Heating,Cooling&AirQuality|WaterH...           ₹1,439
# 1299  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...           ₹4,995
# 1223  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...             ₹699
# 1388  Home&Kitchen|Heating,Cooling&AirQuality|WaterH...           ₹1,499
# 1275  Home&Kitchen|Kitchen&HomeAppliances|SmallKitch...             ₹699
#
#      actual_price discount_percentage rating rating_count  \
# 1279       ₹2,499                 16%      |          992
# 324          ₹999                 75%    5.0          NaN
# 174        ₹1,999                 80%    5.0            5
# 775        ₹1,000                 50%    5.0           23
# 1201         ₹499                 44%    4.8           28
# 1145       ₹1,999                 28%    4.8       53,803
# 1299      ₹20,049                 75%    4.8        3,964
# 1223       ₹1,599                 56%    4.7        1,729
# 1388       ₹3,500                 57%    4.7        2,591
# 1275       ₹1,599                 56%    4.7        2,300
#
#                                           about_product  \
# 1279  No Installation is provided for this product|1...
# 324   💎[The Fastest Charge] - This iPhone USB C cabl...
# 174   This sturdy and durable cable made of tpe and ...
# 775   Reliable wireless connection up to 10m|Advance...
# 1201  -Make delicious milk foam creamer for your dri...
# 1145  ✔Quick Electric Hot Water Tap Heating tube: hi...
# 1299  VOLTAGE (230 Volts): Instant Vortex Air Fryer ...
# 1223  【Rechargeable Multi-Function Milk Frother】The ...
# 1388  Prolix Auto cut off feature: It is available w...
# 1275                                     Egg Frying Pan
#
#                                                 user_id  \
# 1279  AGTDSNT2FKVYEPDPXAA673AIS44A,AER2XFSWNN4LAUCJ5...
# 324                        AGJC5O5H5BBXWUV7WRIEIOOR3TVQ
# 174   AF7EOXYL5K36BDP6PXF6K2TL5TPA,AEN7NV2P5WNHM7EXC...
# 775   AFLLEPVLIAH2DFSHAZ77KWFM72ZA,AHY2YZWK63CNZ626M...
# 1201  AGRJZJKWKIE573KM5FWPOH4F7YCA,AEHV4VOLDQX5XYA42...
# 1145  AEU7DVFEL43XZ6T4D572W2ZLBRKQ,AGWOH7CFDMUVW52NM...
# 1299  AGXJAYXZKJ6NCPSLX57MXJLQ3F6Q,AEQYSJWBP6DN2IV2L...
# 1223  AGMHHTX7GPWHZAUTEYQOFEEDFMDQ,AEJJGJQCIEPL3ZBNU...
# 1388  AEVX4JV3C4QR3Y3V3RJXQ2WZAR4Q,AHR5JZBK66QYZSEJ3...
# 1275  AFZ2YKWX4KR7MWSA6UOMEGGHT32A,AEP6WZ7AR6XDQSBFS...
#
#                                               user_name  \
# 1279  Divya,Dr Nefario,Deekshith,Preeti,Prasanth R,P...
# 324                                         Abdul Gafur
# 174   Amazon Customer,kamal sahota,Pankaj,luvsmplcty...
# 775   Rambeer kumar,Ramesh,Digambar Shelke,awadhesh ...
# 1201  Amazon Customer,Neha Mehta,Nischal Agarwal,tha...
# 1145                    Yogita g.,Amazon Customer,Mimsy
# 1299  nikhil,Rituja Ray,Prasan Krishnan Karthikeyan,...
# 1223  123MovieTime,Ravneet S.,Akash,Mohd Amaan,Panka...
# 1388  Srujan kumar,Sadhu s.,parveen sharma,Patel kau...
# 1275  Nitin G.,Veerasomachary,Roshan,Kunwar Indransh...
#
#                                               review_id  \
# 1279  R2KKTKM4M9RDVJ,R1O692MZOBTE79,R2WRSEWL56SOS4,R...
# 324                                       RQXD5SAMMPC6L
# 174   R1L2JNO4Y3BHYF,R2346F22YLZ9IG,R3A4GAQTCPE5U7,R...
# 775   R76XPXMKXLWKH,R23S77AWPH5FP5,RK7Q6W5FOPESC,R2X...
# 1201  R3907SDNN9VR5Y,R1NNMXA39722T8,RXQNT49DKJ26S,R2...
# 1145       R2WHW4PEF14WOD,R2DCCZWUGI0O0K,R1FA1HH6VL1RAL
# 1299  R2FHIBV8JE4CTB,R315K0BCU0KVKO,RD129PA7KQQOR,R3...
# 1223  R1YXOQ6ZZI33LZ,R17FVMZGPYPOYZ,R23NCERA0R891T,R...
# 1388  RBPM3YRVWMMMK,RVY7BZCJPHJZU,R3KXHKIGWPT7IS,R1K...
# 1275  R2DHTJGY77MOP0,R36IXNHZC037AW,R3GPHUMRV75VWK,R...
#
#                                            review_title  \
# 1279  Decent product,doesn't pick up sand,Ok ok,Must...
# 324                                     Awesome Product
# 174   Good,Superb quality,Good products  nice one,Wo...
# 775   Very responsive and stylish mouse,Simply Aweso...
# 1201  Oratech Best Coffee Frother,Great,My review ab...
# 1145  Best Product,It’s expansive but it works well ...
# 1299  Loved it,Good product,Good product,It's easy t...
# 1223  Nice product,Not as effective as claimed, just...
# 1388  Felt very useful 👌 but cable is short,Good in ...
# 1275  Amazing! Value for money!,Very easy to use,2 i...
#
#                                          review_content  \
# 1279  Does the job well,doesn't work on sand. though...
# 324   Quick delivery.Awesome ProductPacking was good...
# 174   Product is good in quality. Working good with ...
# 775   I really like this wireless mouse it has becam...
# 1201  Overall, I love this Oratech Coffee frother an...
# 1145  Must buy best Fabulous product I recommend thi...
# 1299  I have used multiple air fryers. But this one ...
# 1223  Value for money,Not as effective as claimed, j...
# 1388  I like instant heating, I didn't get warranty ...
# 1275  Worth buying for eggetarians,Working great so ...
#
#                                                img_link  \
# 1279  https://m.media-amazon.com/images/W/WEBP_40237...
# 324   https://m.media-amazon.com/images/I/31-q0xhaTA...
# 174   https://m.media-amazon.com/images/I/317OoQfs1g...
# 775   https://m.media-amazon.com/images/I/31+Rg6Z46d...
# 1201  https://m.media-amazon.com/images/W/WEBP_40237...
# 1145  https://m.media-amazon.com/images/I/41+t2HWvwF...
# 1299  https://m.media-amazon.com/images/W/WEBP_40237...
# 1223  https://m.media-amazon.com/images/I/51oN+8Zs5Y...
# 1388  https://m.media-amazon.com/images/W/WEBP_40237...
# 1275  https://m.media-amazon.com/images/W/WEBP_40237...
#
#                                            product_link
# 1279  https://www.amazon.in/Eureka-Forbes-Vacuum-Cle...
# 324   https://www.amazon.in/REDTECH-Lightning-Certif...
# 174   https://www.amazon.in/Syncwire-Cable-Charging-...
# 775   https://www.amazon.in/Wireless-Connection-Batt...
# 1201  https://www.amazon.in/Oratech-electric-cappucc...
# 1145  https://www.amazon.in/Swiffer-Instant-Electric...
# 1299  https://www.amazon.in/Instant-Vortex-2QT-EvenC...
# 1223  https://www.amazon.in/FIGMENT-Rechargeable-Dec...
# 1388  https://www.amazon.in/Spring-Chef-Stainless-Re...
# 1275  https://www.amazon.in/Multifunctional-Electric...

# %% [markdown]
# Most Discounted Products

# %%
df.sort_values(by='discounted_price', ascending=False).head(10)
# Out:
#       product_id                                       product_name  \
# 806   B08JMC1988  boAt Stone 180 5W Bluetooth Speaker with Upto ...
# 869   B07KRCW6LZ  TP-Link Nano AC600 USB Wi-Fi Adapter(Archer T2...
# 444   B09MZCQYHZ  Ambrane 10000mAh Slim Power Bank, 20W Fast Cha...
# 447   B095RTJH1M  Spigen EZ Fit Tempered Glass Screen Protector ...
# 767   B08YD264ZS  Tarkan Portable Folding Laptop Desk for Bed, L...
# 451   B08RZ5K9YH  MI 33W SonicCharge 2.0 USB Charger for Cellula...
# 891   B0B2931FCV  ZEBRONICS Zeb-Sound Bomb N1 True Wireless in E...
# 797   B082FTPRSK  Zinq Five Fan Cooling Pad and Laptop Stand wit...
# 1334  B09474JWN6  HealthSense Rechargeable Lint Remover for Clot...
# 413   B0993BB11X  Ambrane 10000mAh Slim Power Bank, 20W Fast Cha...
#
#                                                category discounted_price  \
# 806      Electronics|HomeAudio|Speakers|OutdoorSpeakers             ₹999
# 869   Computers&Accessories|NetworkingDevices|Networ...             ₹999
# 444   Electronics|Mobiles&Accessories|MobileAccessor...             ₹999
# 447   Electronics|Mobiles&Accessories|MobileAccessor...             ₹999
# 767   Computers&Accessories|Accessories&Peripherals|...             ₹999
# 451   Electronics|Mobiles&Accessories|MobileAccessor...             ₹999
# 891   Electronics|Headphones,Earbuds&Accessories|Hea...             ₹999
# 797   Computers&Accessories|Accessories&Peripherals|...             ₹999
# 1334  Home&Kitchen|Kitchen&HomeAppliances|Vacuum,Cle...             ₹999
# 413   Electronics|Mobiles&Accessories|MobileAccessor...             ₹999
#
#      actual_price discount_percentage rating rating_count  \
# 806        ₹2,490                 60%    4.1       18,331
# 869        ₹1,599                 38%    4.3       12,093
# 444        ₹1,599                 38%    4.0        7,222
# 447        ₹2,899                 66%    4.6       26,603
# 767        ₹2,499                 60%    4.3        1,690
# 451        ₹1,999                 50%    4.3        1,777
# 891        ₹4,199                 76%    3.5        1,913
# 797        ₹1,999                 50%    4.2       27,441
# 1334       ₹1,500                 33%    4.2          386
# 413        ₹1,599                 38%    4.0        7,222
#
#                                           about_product  \
# 806   Stone 180 comes equipped with 1.75" Dynamic Dr...
# 869   High Speed WiFi —— Up to 600Mbps speeds with 2...
# 444   Power-packed 10000mAh- Lithium Polymer 10000mA...
# 447   Compatibility ; Glass Screen Protector Compati...
# 767   ✅【Smart Design - 2021 Model】This new Gen. lapt...
# 451   100cm Fast Charging Type C Cable Included|Over...
# 891   Wireless BT v5.2 TWS earbuds with easy to use ...
# 797   The notebook cooler has a unique design and ad...
# 1334  RECHARGEABLE CORDLESS: Long lasting multiple U...
# 413   Power-packed 10000mAh- Lithium Polymer 10000mA...
#
#                                                 user_id  \
# 806   AEJYXUANEWSM2G7VHRZDANCYLPYQ,AGGUTNEUBYL4DWFU3...
# 869   AEM356PVXFHAXWV56KDO75FS5WPA,AHVTFTBEBRRJCG72Z...
# 444   AFZRJWGYUFNULZQLL27PLZYMTYFA,AELUUSXPQUT3DD5LO...
# 447   AFDITJCB5D4EOPYZKGP5RGRJFVLA,AHFCEAPRZ44PZ2EVR...
# 767   AHXVJ4RECEDVRCX2R7BYOMRO7KJQ,AEUNZGZ7IQFCJEFHU...
# 451   AEJKUZQM36XSQ4JKVC4UBWE5YJJA,AGQWUC553PFV7YGNW...
# 891   AE2XBDOYDMXVHS6NWFKR363SXNEQ,AFEWNQ3WHCXFV334R...
# 797   AEKJYGHV46KB5CVLQS54Y77VRNDA,AGDONPW67V5WB44YK...
# 1334  AFXT4M4YZCGYWUG22BMXEOB7VUOA,AEZWBVOWAZGCLKUNZ...
# 413   AFZRJWGYUFNULZQLL27PLZYMTYFA,AELUUSXPQUT3DD5LO...
#
#                                               user_name  \
# 806   Meghana,Udit narayan gupta,R.sasikumr,Sweta Ch...
# 869   Paul Joe,Simon Rex P. J.,Santhosh,Rajat Singh ...
# 444   RAMKISAN,Pawan Kumar yadav,Nikhil,Drew Arsenic...
# 447   Abdul Moiz,Rupesh Patil,Devashis,Amruth Ramesh...
# 767   Divya Sood,Athar,RINO,Purvesh,R Periyasamy,Ama...
# 451   sarangam guru prasad,Aniruddha Mahamuni,Naresh...
# 891   Amos b.,Srimanth,JATIN BHATIA,PARTHIBAN LUCKY,...
# 797   Abraham M.,Varun,Sandeep J,B HYNDAVI,Charan Te...
# 1334  GB SLG,Jemin,Ashwini Vetekar,Kusum,sonu ali,Am...
# 413   RAMKISAN,Pawan Kumar yadav,Nikhil,Drew Arsenic...
#
#                                               review_id  \
# 806   R16I46MPR0NO8S,RC8A7CPLOKIQ1,RXMRIDNTYYGO0,RBD...
# 869   RSNHWPVLK9SAQ,R2RKKAN3GRHI0G,R1FVWKC3ORTKKX,RT...
# 444   R83JPRO9V52P,R3UTU1ETF9YL12,RSOL1K3LF3E2I,R377...
# 447   RE1RVB3YIBPKD,R41RLIIPI7UUH,R232FT7DXDWX1C,R1V...
# 767   R236C7OLIIWMX1,R3PN1HMPH33439,RDW68UNQSWDHI,R3...
# 451   RM0S8X7RALDXR,R2118P20L5XNMT,RRO90ETYUURUA,R32...
# 891   R3TGQK7IIJLS03,RUOMB8W6YK7QR,R3CFBAHDNZG57Q,R1...
# 797   R2OP8NFYDOS39J,R2RQTRMPYMIHAE,R2V61JLM0WASPT,R...
# 1334  RVV3VEBYM65XS,R25CPGMH2YOEGC,RL1N0IR94UURO,RJD...
# 413   R83JPRO9V52P,R3UTU1ETF9YL12,RSOL1K3LF3E2I,R377...
#
#                                            review_title  \
# 806   Stone 180 is good as a portable speaker.,Good ...
# 869   Dual Bandwidth,It's good,Simple and effective,...
# 444   Nice product,Good,Kaam sahi karta hai ji,Woks ...
# 447   Easy to install but a bit slippery,Very good p...
# 767   Good,Quite Good, just a little too costly, but...
# 451   Very good power charger,Good and original item...
# 891   Good price good quality,Good for Music, Bad fo...
# 797   Good for cooling,Not good for gaming,quality n...
# 1334  👍 nice,Lint removed instantly and effortlessly...
# 413   Nice product,Good,Kaam sahi karta hai ji,Woks ...
#
#                                          review_content  \
# 806   Bought at 800.Sound quality is good enough.Eas...
# 869   Easy to use,It's good and useful,Had been usin...
# 444   I am very happy after using it.  This power ba...
# 447   I used my 13 pro without a screen guard for a ...
# 767   ,Package arrived in a big box, inside the tabl...
# 451   Very fast charging,It's a original item and do...
# 891   It’s a good product in this price, I would har...
# 797   After testing a couple of times It seemed as i...
# 1334  Like,Loved the product alot. After cleaning of...
# 413   I am very happy after using it.  This power ba...
#
#                                                img_link  \
# 806   https://m.media-amazon.com/images/W/WEBP_40237...
# 869   https://m.media-amazon.com/images/I/31EHCPHbSl...
# 444   https://m.media-amazon.com/images/I/31oA0-q5Uz...
# 447   https://m.media-amazon.com/images/I/41Usew0lrW...
# 767   https://m.media-amazon.com/images/W/WEBP_40237...
# 451   https://m.media-amazon.com/images/I/21Z1HsPvyT...
# 891   https://m.media-amazon.com/images/W/WEBP_40237...
# 797   https://m.media-amazon.com/images/W/WEBP_40237...
# 1334  https://m.media-amazon.com/images/W/WEBP_40237...
# 413   https://m.media-amazon.com/images/I/21e5ZrIutK...
#
#                                            product_link
# 806   https://www.amazon.in/boAt-Stone-Bluetooth-Spe...
# 869   https://www.amazon.in/TP-Link-Archer-T2U-Nano-...
# 444   https://www.amazon.in/Ambrane-Multi-Layer-Prot...
# 447   https://www.amazon.in/Spigen-Tempered-Screen-P...
# 767   https://www.amazon.in/Tarkan-Portable-Folding-...
# 451   https://www.amazon.in/33W-SonicCharge-2-0-Char...
# 891   https://www.amazon.in/Zebronics-Zeb-Sound-N1-B...
# 797   https://www.amazon.in/Zinq-Technologies-Cool-S...
# 1334  https://www.amazon.in/HealthSense-New-Feel-Rec...
# 413   https://www.amazon.in/Ambrane-Multi-Layer-Prot...

# %% [markdown]
# Rating Distribution

# %%
plt.figure(figsize=(10,6))
sns.histplot(df['rating'], bins=20)
plt.title("Distribution of Product Ratings")
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Save Chart

# %%
plt.savefig('../outputs/rating_distribution.png')
